# %%
import pandas as pd

data = {
    "Name": ["Ravi", "Sita", "John", "Asha"],
    "Age": [23, 21, 25, 22],
    "Marks": [85, 90, 78, 88]
}

df = pd.DataFrame(data)

# Column-wise subsetting
subset = df[["Name", "Marks"]]

print(subset)
# Out:
#    Name  Marks
# 0  Ravi     85
# 1  Sita     90
# 2  John     78
# 3  Asha     88
